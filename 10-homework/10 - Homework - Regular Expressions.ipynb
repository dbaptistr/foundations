# %% [markdown]
# # Homework 10: Cleaning data with Regular Expressions
#
# Time to use regular expressions!
#
# # Hints and notes
#
# ### Opening files in subdirectories
#
# Notice that this notebook might be **homework/**, but!!! the csvs and text files might be in **homework/scraped/** or **/homework/scraped/minutes_pdfs** or **/homework/pdfs/**. To open a file in a subdirectory, instead of having the filename be `"file.csv"` you'll just use `"some/subfolder/file.csv"`
#
# ### Opening text files
#
# This will open up a file, read it in and show you the first 500 characters.
#
# ```python
# contents = open("your-filename.txt").read()
# contents[0:500]
# ```
#
# > You might need `open("your-filename.txt", encoding="utf8").read()`
#
# ### Using regex
#
# For some dumb reason you need to put `r` in front of the string you use when you're talking about regex. Just plain `"(\d\d\d)"` will usually work, but *sometimes* it won't and you'll need `r"(\d\d\d)`. It's best to just use the `r` all of the time, if you can remember!
#
# ### Using `.str.extract`
#
# When you use `.str.extract`, you're always going to **capture one thing** and save it to a new column. You need to wrap the things you're interested in with parenthesis `(` `)`.
#
# ```python
# df['phone_number'] = df['old_column'].str.extract(r"My phone number is (\d\d\d-\d\d\d-\d\d\d\d)")
# ```
#
# ### Setting pandas options
#
# Pandas has a lot of options, like how many columns or rows it will show you, or how many characters it will show in a column before it stops showing you anything. Here are a few useful ones:
#
# * `display.max_cols`: Number of columns to show at once
# * `display.max_rows`: Number of rows to show at once
# * `display.max_colwidth`: Maximum number of characters displayed from a string
#
# You can set them using `pd.set_option("display.max_rows", 1000)`, for example, to show 1000 rows at a time. You can find a lot more at https://pandas.pydata.org/pandas-docs/stable/generated/pandas.set_option.html
#
# ### Regular expressions reference
#
# I personally think http://www.regular-expressions.info/ is a wonderful wonderful reference (and tutorial), even if it's ugly! But here's a quick reference for you:
#
# * `\d` is a digit
# * `\d*` is zero or more digits
# * `\d+` is one or more digits
# * `.` matches anything for ONE character
# * `.*` is "give me anything forever"
# * `\s` is whitespace, a.k.a. spaces and tabs
# * `\w` is a word character, which includes capital and lowercase letters, numbers and hyphens.
# * You can put `*` after anything, so `\w*` would mean "as many word characters as you can find"
# * `\b` is a word boundary (you'll need the `r""` thing for this one)
# * `( )` is a "capture group" for saving something
# * `\1` is used when doing find/replace to say "put the first captured group here" (note, it's a dollar sign instead of a backslash in some editors)
# * `[ABCDE]` is a character class, which means "match one of these, I don't care which"
# * dollar sign means "end of the line"
# * caret ^ means "beginning of the line"
# * `\.` means "no really seriously I mean a period not just anything"
# * You can use `\` with anything else that would normally be a special character, too, not just periods. `(` or `[` or whatever.
#
# ### Cleaning up extracted columns
#
# Sometimes you get `\n` (newlines) or spaces or `\t` (tabs) or stuff at the beginning or the end of your column. `.str.strip()` will usually take care of that, just attach it after your `.str.extract()`
#
# After you extract something, it's still a string even though you look at it and know it's a number. Use `.astype(int)` to turn it into an integer (no decimal) or `.astype(float)` to turn it into a float (yes decimal)
#
# ### Writing regular expressions in general
#
# Even if I'm using regex in pandas or Python, I like to test them in my text editor with "Find." The highlighting really helps me see if I'm matching things! I also like to think "what stays the same?" when designing patterns, write those parts first, then fill in the blanks with what I want to capture.

# %% [markdown]
# ## Importing
#
# There might be more, I just wanted to put this up here for the `pd.set_option` part. It allows you to see a lot of content in a single column of pandas, which will be important for some parts below.

# %%
import re
import pandas as pd
pd.set_option('display.max_colwidth', 500)

# %% [markdown]
# # Part 1: Using `.str.extract` to pull data from columns in pandas
#
# ## 1.1 H&M
#
# Open up `hm.csv` from the `scraped` directory. I want **four new columns**:
#
# 1. `price_original`, the original price, one of the new price
# 2. `price_discounted`, the discounted price
# 3. `pct_discount`, the percent discount
# 4. `article_id`, the article id (from the url)
#
# Save as **hm_cleaned.csv**.
#
# **Note:** When you look at it, it... won't look right. I don't know why, pandas is weird. Look at the `price` column by itself using `df['price']` before you write your regex.
#
# **Tip:** Remember that `$` is a special regex symbol! You might need to escape it.
#
# **Tip:** When doing `.str.extract`, the whole match doesn't get captured, only what you put `()` around! Think about anchoring to different points of the string, or things in the string.
#
# **Tip:** Not all prices have cents!
#
# **Tip:** Your first instinct about how to compute the percent discount is probably wrong

# %%
df = pd.read_csv("scraped/hm.csv")

# %%
df.head()
# Out:
#                            name          price  \
# 0  Washed Linen Duvet Cover Set    $59.99 $129
# 1           Candle in Glass Jar   $6.99 $17.99
# 2        Glittery Cushion Cover   $7.99 $17.99
# 3  Textured-weave Cushion Cover   $6.99 $12.99
# 4                Stoneware Bowl  $17.99 $24.99
#
#                                                   url
# 0  http://www.hm.com/us/product/13472?article=13472-N
# 1  http://www.hm.com/us/product/35079?article=35079-D
# 2  http://www.hm.com/us/product/72462?article=72462-A
# 3  http://www.hm.com/us/product/58926?article=58926-C
# 4  http://www.hm.com/us/product/74242?article=74242-A

# %%
df.price.head()
# Out:
# 0      $59.99 $129
# 1     $6.99 $17.99
# 2     $7.99 $17.99
# 3     $6.99 $12.99
# 4    $17.99 $24.99
# Name: price, dtype: object

# %%
df['original_price'] = df.price.str.extract("( \$.*)")
df['discounted_price'] = df.price.str.extract("(\$.* )")
df.head()
# Out:
#                            name          price  \
# 0  Washed Linen Duvet Cover Set    $59.99 $129
# 1           Candle in Glass Jar   $6.99 $17.99
# 2        Glittery Cushion Cover   $7.99 $17.99
# 3  Textured-weave Cushion Cover   $6.99 $12.99
# 4                Stoneware Bowl  $17.99 $24.99
#
#                                                   url original_price  \
# 0  http://www.hm.com/us/product/13472?article=13472-N           $129
# 1  http://www.hm.com/us/product/35079?article=35079-D         $17.99
# 2  http://www.hm.com/us/product/72462?article=72462-A         $17.99
# 3  http://www.hm.com/us/product/58926?article=58926-C         $12.99
# 4  http://www.hm.com/us/product/74242?article=74242-A         $24.99
#
#   discounted_price
# 0          $59.99
# 1           $6.99
# 2           $7.99
# 3           $6.99
# 4          $17.99

# %%
df['original_price'] = df.original_price.str.extract("(\d.*)")
df['discounted_price'] = df.discounted_price.str.extract("(\d.*)")
df.head()
# Out:
#                            name          price  \
# 0  Washed Linen Duvet Cover Set    $59.99 $129
# 1           Candle in Glass Jar   $6.99 $17.99
# 2        Glittery Cushion Cover   $7.99 $17.99
# 3  Textured-weave Cushion Cover   $6.99 $12.99
# 4                Stoneware Bowl  $17.99 $24.99
#
#                                                   url original_price  \
# 0  http://www.hm.com/us/product/13472?article=13472-N            129
# 1  http://www.hm.com/us/product/35079?article=35079-D          17.99
# 2  http://www.hm.com/us/product/72462?article=72462-A          17.99
# 3  http://www.hm.com/us/product/58926?article=58926-C          12.99
# 4  http://www.hm.com/us/product/74242?article=74242-A          24.99
#
#   discounted_price
# 0           59.99
# 1            6.99
# 2            7.99
# 3            6.99
# 4           17.99

# %%
df['original_price'] = df['original_price'].astype(float)
df['discounted_price'] = df['discounted_price'].astype(float)
df.dtypes
# Out:
# name                 object
# price                object
# url                  object
# original_price      float64
# discounted_price    float64
# dtype: object

# %%
df['pct_discount'] = (df.original_price - df.discounted_price)/df.original_price * 100
df.head()
# Out:
#                            name          price  \
# 0  Washed Linen Duvet Cover Set    $59.99 $129
# 1           Candle in Glass Jar   $6.99 $17.99
# 2        Glittery Cushion Cover   $7.99 $17.99
# 3  Textured-weave Cushion Cover   $6.99 $12.99
# 4                Stoneware Bowl  $17.99 $24.99
#
#                                                   url  original_price  \
# 0  http://www.hm.com/us/product/13472?article=13472-N          129.00
# 1  http://www.hm.com/us/product/35079?article=35079-D           17.99
# 2  http://www.hm.com/us/product/72462?article=72462-A           17.99
# 3  http://www.hm.com/us/product/58926?article=58926-C           12.99
# 4  http://www.hm.com/us/product/74242?article=74242-A           24.99
#
#    discounted_price  pct_discount
# 0             59.99     53.496124
# 1              6.99     61.145081
# 2              7.99     55.586437
# 3              6.99     46.189376
# 4             17.99     28.011204

# %%
df['article_id'] = df.url.str.extract("(\d{5}-.*)")
df.head()
# Out:
#                            name          price  \
# 0  Washed Linen Duvet Cover Set    $59.99 $129
# 1           Candle in Glass Jar   $6.99 $17.99
# 2        Glittery Cushion Cover   $7.99 $17.99
# 3  Textured-weave Cushion Cover   $6.99 $12.99
# 4                Stoneware Bowl  $17.99 $24.99
#
#                                                   url  original_price  \
# 0  http://www.hm.com/us/product/13472?article=13472-N          129.00
# 1  http://www.hm.com/us/product/35079?article=35079-D           17.99
# 2  http://www.hm.com/us/product/72462?article=72462-A           17.99
# 3  http://www.hm.com/us/product/58926?article=58926-C           12.99
# 4  http://www.hm.com/us/product/74242?article=74242-A           24.99
#
#    discounted_price  pct_discount article_id
# 0             59.99     53.496124    13472-N
# 1              6.99     61.145081    35079-D
# 2              7.99     55.586437    72462-A
# 3              6.99     46.189376    58926-C
# 4             17.99     28.011204    74242-A

# %% [markdown]
# ## 1.2 Sci-Fi Authors
#
# Open up `sci-fi.csv` to clean. Get rid of the `\n` on the title and and give me six new columns:
#
# * `avg_rating`
# * `rating_count`
# * `total_score`
# * `score_votes`
# * `series` the series the book belongs to
# * `series_no` the book in the series that it is
#
# For series, I'm talking about e.g. `(The Hunger Games, #1)` is `series` "The Hunter Games" and `series_no` 1.
#
# Save as **sci-fi_cleaned.csv**.
#
# **Tip:** You don't need regex to clean the title - there's a special thing that removes whitespace from the beginning/end of strings
#
# **Tip:** Remember that `(` and `)` are special characters
#
# **BONUS:** When you make the `total_score` column, pay close attention to it. If you notice the problem, fix it.
#
# **BONUS:** You don't need these columns to be numbers, but life would be better if they were.

# %%
df = pd.read_csv("scraped/sci-fi.csv")
df.head()
# Out:
#                             full_rating  \
# 0     4.07 avg rating — 785,502 ratings
# 1   4.34 avg rating — 5,212,935 ratings
# 2     3.76 avg rating — 922,308 ratings
# 3     4.04 avg rating — 702,272 ratings
# 4      4.06 avg rating — 77,664 ratings
#
#                                                                                              full_score  \
# 0  \nscore: 28,539,\n              and\n292 people voted\n               \n              \n
# 1  \nscore: 27,566,\n              and\n282 people voted\n               \n              \n
# 2  \nscore: 20,049,\n              and\n205 people voted\n               \n              \n
# 3  \nscore: 17,684,\n              and\n185 people voted\n               \n              \n
# 4  \nscore: 16,070,\n              and\n165 people voted\n               \n              \n
#
#    rank                                                  title  \
# 0     1                                \nThe Handmaid's Tale\n
# 1     2            \nThe Hunger Games (The Hunger Games, #1)\n
# 2     3             \nFrankenstein, or The Modern Prometheus\n
# 3     4  \nA Wrinkle in Time (A Wrinkle in Time Quintet, #1)\n
# 4     5                          \nThe Left Hand of Darkness\n
#
#                                                       url
# 0                    /book/show/38447.The_Handmaid_s_Tale
# 1                     /book/show/2767052-the-hunger-games
# 2  /book/show/18490.Frankenstein_or_The_Modern_Prometheus
# 3                      /book/show/18131.A_Wrinkle_in_Time
# 4              /book/show/18423.The_Left_Hand_of_Darkness

# %%
df['avg_rating'] = df.full_rating.str.extract("(\d\.\d\d)")
df['rating_count'] = df.full_rating.str.extract("(\d?\d?\d?,?\d?\d?\d?,?\d?\d?\d?,?\d\d\d)")
df['total_score'] = df.full_score.str.extract("(\d?\d?\d?\,?\d?\d?\d)")
df['score_votes'] = df.full_score.str.extract("(\d+ )")
df['series'] = df.title.str.extract("(\(\w.*,)")
df['series_no'] = df.title.str.extract("(\#\d+,* *\#*\d*)")

# %%
df
# Out:
#                                           full_rating  \
# 0                   4.07 avg rating — 785,502 ratings
# 1                 4.34 avg rating — 5,212,935 ratings
# 2                   3.76 avg rating — 922,308 ratings
# 3                   4.04 avg rating — 702,272 ratings
# 4                    4.06 avg rating — 77,664 ratings
# 5                 4.23 avg rating — 2,345,974 ratings
# 6                 4.30 avg rating — 2,049,239 ratings
# 7                 4.12 avg rating — 1,379,452 ratings
# 8                    4.19 avg rating — 57,605 ratings
# 9                    4.20 avg rating — 53,473 ratings
# 10  really liked it 4.00 avg rating — 176,024 ratings
# 11                4.03 avg rating — 1,932,930 ratings
# 12                3.95 avg rating — 1,355,662 ratings
# 13                   4.03 avg rating — 38,534 ratings
# 14                   4.10 avg rating — 36,316 ratings
# 15                   4.17 avg rating — 46,116 ratings
# 16                   4.12 avg rating — 22,554 ratings
# 17                   3.97 avg rating — 53,063 ratings
# 18                  4.10 avg rating — 106,206 ratings
# 19                   4.14 avg rating — 31,668 ratings
# 20                   4.13 avg rating — 26,705 ratings
# 21                   4.29 avg rating — 18,831 ratings
# 22                   4.31 avg rating — 20,045 ratings
# 23                  3.84 avg rating — 793,665 ratings
# 24                  4.06 avg rating — 979,341 ratings
# 25                   3.69 avg rating — 33,313 ratings
# 26                   4.44 avg rating — 12,743 ratings
# 27                    3.88 avg rating — 1,466 ratings
# 28                   4.08 avg rating — 16,555 ratings
# 29                   4.06 avg rating — 81,801 ratings
# ..                                                ...
# 70                      4.41 avg rating — 336 ratings
# 71                  4.02 avg rating — 206,616 ratings
# 72                      3.83 avg rating — 799 ratings
# 73                    3.55 avg rating — 4,568 ratings
# 74                      3.78 avg rating — 215 ratings
# 75                    4.01 avg rating — 8,590 ratings
# 76                      4.46 avg rating — 256 ratings
# 77                      4.18 avg rating — 748 ratings
# 78                   4.05 avg rating — 10,873 ratings
# 79                    4.32 avg rating — 3,203 ratings
# 80                      4.48 avg rating — 244 ratings
# 81                    3.88 avg rating — 5,588 ratings
# 82                      4.19 avg rating — 367 ratings
# 83                       4.28 avg rating — 93 ratings
# 84                  3.99 avg rating — 366,089 ratings
# 85                       4.91 avg rating — 56 ratings
# 86                      3.86 avg rating — 134 ratings
# 87                    4.04 avg rating — 3,160 ratings
# 88                    4.01 avg rating — 4,504 ratings
# 89                    3.91 avg rating — 9,782 ratings
# 90                   3.74 avg rating — 11,925 ratings
# 91                    4.03 avg rating — 3,338 ratings
# 92                   4.05 avg rating — 57,864 ratings
# 93                      3.82 avg rating — 116 ratings
# 94                    4.19 avg rating — 3,328 ratings
# 95                    4.17 avg rating — 3,717 ratings
# 96                  3.78 avg rating — 103,428 ratings
# 97                       4.16 avg rating — 97 ratings
# 98                      3.85 avg rating — 111 ratings
# 99                    3.83 avg rating — 3,244 ratings
#
#                                                                                               full_score  \
# 0   \nscore: 28,539,\n              and\n292 people voted\n               \n              \n
# 1   \nscore: 27,566,\n              and\n282 people voted\n               \n              \n
# 2   \nscore: 20,049,\n              and\n205 people voted\n               \n              \n
# 3   \nscore: 17,684,\n              and\n185 people voted\n               \n              \n
# 4   \nscore: 16,070,\n              and\n165 people voted\n               \n              \n
# 5   \nscore: 12,935,\n              and\n134 people voted\n               \n              \n
# 6   \nscore: 12,261,\n              and\n128 people voted\n               \n              \n
# 7   \nscore: 11,238,\n              and\n117 people voted\n               \n              \n
# 8   \nscore: 10,246,\n              and\n107 people voted\n               \n              \n
# 9    \nscore: 9,907,\n              and\n104 people voted\n               \n              \n
# 10   \nscore: 9,628,\n              and\n102 people voted\n               \n              \n
# 11   \nscore: 9,423,\n              and\n100 people voted\n               \n              \n
# 12    \nscore: 8,250,\n              and\n88 people voted\n               \n              \n
# 13    \nscore: 8,175,\n              and\n88 people voted\n               \n              \n
# 14    \nscore: 7,523,\n              and\n81 people voted\n               \n              \n
# 15    \nscore: 6,571,\n              and\n69 people voted\n               \n              \n
# 16    \nscore: 6,418,\n              and\n68 people voted\n               \n              \n
# 17    \nscore: 6,257,\n              and\n70 people voted\n               \n              \n
# 18    \nscore: 6,238,\n              and\n68 people voted\n               \n              \n
# 19    \nscore: 5,999,\n              and\n64 people voted\n               \n              \n
# 20    \nscore: 5,933,\n              and\n64 people voted\n               \n              \n
# 21    \nscore: 5,698,\n              and\n61 people voted\n               \n              \n
# 22    \nscore: 5,046,\n              and\n54 people voted\n               \n              \n
# 23    \nscore: 5,012,\n              and\n53 people voted\n               \n              \n
# 24    \nscore: 4,899,\n              and\n54 people voted\n               \n              \n
# 25    \nscore: 4,413,\n              and\n48 people voted\n               \n              \n
# 26    \nscore: 4,398,\n              and\n48 people voted\n               \n              \n
# 27    \nscore: 4,394,\n              and\n45 people voted\n               \n              \n
# 28    \nscore: 4,249,\n              and\n47 people voted\n               \n              \n
# 29    \nscore: 4,245,\n              and\n46 people voted\n               \n              \n
# ..                                                                                                   ...
# 70    \nscore: 1,817,\n              and\n19 people voted\n               \n              \n
# 71    \nscore: 1,775,\n              and\n20 people voted\n               \n              \n
# 72    \nscore: 1,772,\n              and\n19 people voted\n               \n              \n
# 73    \nscore: 1,740,\n              and\n22 people voted\n               \n              \n
# 74    \nscore: 1,698,\n              and\n17 people voted\n               \n              \n
# 75    \nscore: 1,692,\n              and\n22 people voted\n               \n              \n
# 76    \nscore: 1,687,\n              and\n18 people voted\n               \n              \n
# 77    \nscore: 1,684,\n              and\n18 people voted\n               \n              \n
# 78    \nscore: 1,683,\n              and\n24 people voted\n               \n              \n
# 79    \nscore: 1,575,\n              and\n19 people voted\n               \n              \n
# 80    \nscore: 1,565,\n              and\n17 people voted\n               \n              \n
# 81    \nscore: 1,564,\n              and\n19 people voted\n               \n              \n
# 82    \nscore: 1,559,\n              and\n17 people voted\n               \n              \n
# 83    \nscore: 1,495,\n              and\n16 people voted\n               \n              \n
# 84    \nscore: 1,461,\n              and\n16 people voted\n               \n              \n
# 85    \nscore: 1,458,\n              and\n16 people voted\n               \n              \n
# 86    \nscore: 1,455,\n              and\n16 people voted\n               \n              \n
# 87    \nscore: 1,420,\n              and\n18 people voted\n               \n              \n
# 88    \nscore: 1,380,\n              and\n15 people voted\n               \n              \n
# 89    \nscore: 1,323,\n              and\n18 people voted\n               \n              \n
# 90    \nscore: 1,316,\n              and\n15 people voted\n               \n              \n
# 91    \nscore: 1,301,\n              and\n16 people voted\n               \n              \n
# 92    \nscore: 1,285,\n              and\n16 people voted\n               \n              \n
# 93    \nscore: 1,278,\n              and\n14 people voted\n               \n              \n
# 94    \nscore: 1,240,\n              and\n16 people voted\n               \n              \n
# 95    \nscore: 1,197,\n              and\n16 people voted\n               \n              \n
# 96    \nscore: 1,174,\n              and\n13 people voted\n               \n              \n
# 97    \nscore: 1,170,\n              and\n13 people voted\n               \n              \n
# 98    \nscore: 1,169,\n              and\n13 people voted\n               \n              \n
# 99    \nscore: 1,155,\n              and\n16 people voted\n               \n              \n
#
#     rank                                                                title  \
# 0      1                                              \nThe Handmaid's Tale\n
# 1      2                          \nThe Hunger Games (The Hunger Games, #1)\n
# 2      3                           \nFrankenstein, or The Modern Prometheus\n
# 3      4                \nA Wrinkle in Time (A Wrinkle in Time Quintet, #1)\n
# 4      5                                        \nThe Left Hand of Darkness\n
# 5      6                                        \nDivergent (Divergent, #1)\n
# 6      7                             \nCatching Fire (The Hunger Games, #2)\n
# 7      8                                        \nThe Giver (The Giver, #1)\n
# 8      9                                                 \nThe Dispossessed\n
# 9     10                                                          \nKindred\n
# 10    11                                   \nOryx and Crake (MaddAddam, #1)\n
# 11    12                                \nMockingjay (The Hunger Games, #3)\n
# 12    13                                         \nThe Time Traveler's Wife\n
# 13    14                           \nDoomsday Book (Oxford Time Travel, #1)\n
# 14    15                                              \nThe Lathe of Heaven\n
# 15    16                                    \nThe Sparrow (The Sparrow, #1)\n
# 16    17                          \nShards of Honour  (Vorkosigan Saga, #1)\n
# 17    18                           \nAncillary Justice (Imperial Radch, #1)\n
# 18    19                          \nDragonflight (Dragonriders of Pern, #1)\n
# 19    20                             \nParable of the Sower (Earthseed, #1)\n
# 20    21               \nTo Say Nothing of the Dog (Oxford Time Travel, #2)\n
# 21    22                   \nThe Warrior's Apprentice (Vorkosigan Saga, #2)\n
# 22    23                                   \nBarrayar (Vorkosigan Saga, #7)\n
# 23    24                                          \nThe Host (The Host, #1)\n
# 24    25                                        \nInsurgent (Divergent, #2)\n
# 25    26                                              \nThe Children of Men\n
# 26    27                                    \nMemory (Vorkosigan Saga, #10)\n
# 27    28          \nStarshine: Aurora Rising Book One (Aurora Rhapsody, #1)\n
# 28    29                              \nCrystal Singer (Crystal Singer, #1)\n
# 29    30                           \nThe Year of the Flood  (MaddAddam, #2)\n
# ..   ...                                                                  ...
# 70    71                            \nHive (Species Intervention #6609, #4)\n
# 71    72                                                   \nStation Eleven\n
# 72    73                            \nBaby (Species Intervention #6609, #1)\n
# 73    74                                                   \nThe Female Man\n
# 74    75                                  \nMachinations (Machinations, #1)\n
# 75    76                                                \nThe Speed of Dark\n
# 76    77                   \nEvil Among Us (Species Intervention #6609, #5)\n
# 77    78                                    \nVertigo (Aurora Rhapsody, #2)\n
# 78    79                                  \nCryoBurn (Vorkosigan Saga, #14)\n
# 79    80                            \nSeed to Harvest (Patternmaster, #1-4)\n
# 80    81                         \nThe One (Species Intervention #6609, #6)\n
# 81    82                                 \nDarkover Landfall (Darkover, #1)\n
# 82    83                            \nEcho (Species Intervention #6609, #2)\n
# 83    84          \nHannah's Stolen Men (The Men of Space Station One, #10)\n
# 84    85                                          \nDelirium (Delirium, #1)\n
# 85    86                           \nA Forgotten Kitten (Sea-anan Saga, #2)\n
# 86    87           \nThe Ranchers' Bride (The Men of Space Station One, #2)\n
# 87    88                                               \nRemnant Population\n
# 88    89                                                       \nThe V Girl\n
# 89    90                                     \nThe Word for World is Forest\n
# 90    91                                     \nGrimspace (Sirantha Jax, #1)\n
# 91    92                                       \nThe Wind's Twelve Quarters\n
# 92    93                             \nHis Majesty's Dragon (Temeraire, #1)\n
# 93    94        \nThe Carpenters' Helper (The Men of Space Station One, #5)\n
# 94    95                                        \nInheritor (Foreigner, #3)\n
# 95    96                                          \nInvader (Foreigner, #2)\n
# 96    97                    \nAcross the Universe (Across the Universe, #1)\n
# 97    98                                \nA Lost Kitten (Sea-anan Saga, #1)\n
# 98    99  \nLove Between the Hired Hands (The Men of Space Station One, #4)\n
# 99   100                                                         \nAmmonite\n
#
#                                                        url avg_rating  \
# 0                     /book/show/38447.The_Handmaid_s_Tale       4.07
# 1                      /book/show/2767052-the-hunger-games       4.34
# 2   /book/show/18490.Frankenstein_or_The_Modern_Prometheus       3.76
# 3                       /book/show/18131.A_Wrinkle_in_Time       4.04
# 4               /book/show/18423.The_Left_Hand_of_Darkness       4.06
# 5                            /book/show/13335037-divergent       4.23
# 6                         /book/show/6148028-catching-fire       4.30
# 7                                /book/show/3636.The_Giver       4.12
# 8                        /book/show/13651.The_Dispossessed       4.19
# 9                                 /book/show/60931.Kindred       4.20
# 10                         /book/show/46756.Oryx_and_Crake       4.00
# 11                           /book/show/7260188-mockingjay       4.03
# 12            /book/show/18619684-the-time-traveler-s-wife       3.95
# 13                          /book/show/24983.Doomsday_Book       4.03
# 14                    /book/show/59924.The_Lathe_of_Heaven       4.10
# 15                           /book/show/334176.The_Sparrow       4.17
# 16                       /book/show/61903.Shards_of_Honour       4.12
# 17                   /book/show/17333324-ancillary-justice       3.97
# 18                           /book/show/61975.Dragonflight       4.10
# 19                   /book/show/52397.Parable_of_the_Sower       4.14
# 20              /book/show/77773.To_Say_Nothing_of_the_Dog       4.13
# 21               /book/show/61906.The_Warrior_s_Apprentice       4.29
# 22                               /book/show/61905.Barrayar       4.31
# 23                             /book/show/1656001.The_Host       3.84
# 24                           /book/show/11735983-insurgent       4.06
# 25                    /book/show/41913.The_Children_of_Men       3.69
# 26                                 /book/show/61880.Memory       4.44
# 27                           /book/show/21534331-starshine       3.88
# 28                        /book/show/653711.Crystal_Singer       4.08
# 29                /book/show/6080337-the-year-of-the-flood       4.06
# ..                                                     ...        ...
# 70                                /book/show/17322045-hive       4.41
# 71                      /book/show/20170404-station-eleven       4.02
# 72                                /book/show/15992857-baby       3.83
# 73                        /book/show/908311.The_Female_Man       3.55
# 74                        /book/show/27876301-machinations       3.78
# 75                      /book/show/96063.The_Speed_of_Dark       4.01
# 76                       /book/show/17936909-evil-among-us       4.46
# 77                             /book/show/23150535-vertigo       4.18
# 78                             /book/show/7841670-cryoburn       4.05
# 79                        /book/show/60924.Seed_to_Harvest       4.32
# 80                             /book/show/18044158-the-one       4.48
# 81                     /book/show/673158.Darkover_Landfall       3.88
# 82                                /book/show/15992880-echo       4.19
# 83                 /book/show/21409707-hannah-s-stolen-men       4.28
# 84                            /book/show/11614718-delirium       3.99
# 85                  /book/show/17878961-a-forgotten-kitten       4.91
# 86                  /book/show/13376014-the-ranchers-bride       3.86
# 87                     /book/show/96284.Remnant_Population       4.04
# 88                          /book/show/25437891-the-v-girl       4.01
# 89          /book/show/276767.The_Word_for_World_is_Forest       3.91
# 90                            /book/show/1828067.Grimspace       3.74
# 91             /book/show/77289.The_Wind_s_Twelve_Quarters       4.03
# 92                   /book/show/28876.His_Majesty_s_Dragon       4.05
# 93               /book/show/13518942-the-carpenters-helper       3.82
# 94                              /book/show/57015.Inheritor       4.19
# 95                                /book/show/57014.Invader       4.17
# 96                  /book/show/8235178-across-the-universe       3.78
# 97                       /book/show/16029924-a-lost-kitten       4.16
# 98        /book/show/13482469-love-between-the-hired-hands       3.85
# 99                              /book/show/180270.Ammonite       3.83
#
#    rating_count total_score score_votes                          series  \
# 0       785,502      28,539        292                              NaN
# 1     5,212,935      27,566        282               (The Hunger Games,
# 2       922,308      20,049        205                              NaN
# 3       702,272      17,684        185      (A Wrinkle in Time Quintet,
# 4        77,664      16,070        165                              NaN
# 5     2,345,974      12,935        134                      (Divergent,
# 6     2,049,239      12,261        128               (The Hunger Games,
# 7     1,379,452      11,238        117                      (The Giver,
# 8        57,605      10,246        107                              NaN
# 9        53,473       9,907        104                              NaN
# 10      176,024       9,628        102                      (MaddAddam,
# 11    1,932,930       9,423        100               (The Hunger Games,
# 12    1,355,662       8,250         88                              NaN
# 13       38,534       8,175         88             (Oxford Time Travel,
# 14       36,316       7,523         81                              NaN
# 15       46,116       6,571         69                    (The Sparrow,
# 16       22,554       6,418         68                (Vorkosigan Saga,
# 17       53,063       6,257         70                 (Imperial Radch,
# 18      106,206       6,238         68           (Dragonriders of Pern,
# 19       31,668       5,999         64                      (Earthseed,
# 20       26,705       5,933         64             (Oxford Time Travel,
# 21       18,831       5,698         61                (Vorkosigan Saga,
# 22       20,045       5,046         54                (Vorkosigan Saga,
# 23      793,665       5,012         53                       (The Host,
# 24      979,341       4,899         54                      (Divergent,
# 25       33,313       4,413         48                              NaN
# 26       12,743       4,398         48                (Vorkosigan Saga,
# 27        1,466       4,394         45                (Aurora Rhapsody,
# 28       16,555       4,249         47                 (Crystal Singer,
# 29       81,801       4,245         46                      (MaddAddam,
# ..          ...         ...         ...                             ...
# 70          336       1,817         19     (Species Intervention #6609,
# 71      206,616       1,775         20                              NaN
# 72          799       1,772         19     (Species Intervention #6609,
# 73        4,568       1,740         22                              NaN
# 74          215       1,698         17                   (Machinations,
# 75        8,590       1,692         22                              NaN
# 76          256       1,687         18     (Species Intervention #6609,
# 77          748       1,684         18                (Aurora Rhapsody,
# 78       10,873       1,683         24                (Vorkosigan Saga,
# 79        3,203       1,575         19                  (Patternmaster,
# 80          244       1,565         17     (Species Intervention #6609,
# 81        5,588       1,564         19                       (Darkover,
# 82          367       1,559         17     (Species Intervention #6609,
# 83          NaN       1,495         16   (The Men of Space Station One,
# 84      366,089       1,461         16                       (Delirium,
# 85          NaN       1,458         16                  (Sea-anan Saga,
# 86          134       1,455         16   (The Men of Space Station One,
# 87        3,160       1,420         18                              NaN
# 88        4,504       1,380         15                              NaN
# 89        9,782       1,323         18                              NaN
# 90       11,925       1,316         15                   (Sirantha Jax,
# 91        3,338       1,301         16                              NaN
# 92       57,864       1,285         16                      (Temeraire,
# 93          116       1,278         14   (The Men of Space Station One,
# 94        3,328       1,240         16                      (Foreigner,
# 95        3,717       1,197         16                      (Foreigner,
# 96      103,428       1,174         13            (Across the Universe,
# 97          NaN       1,170         13                  (Sea-anan Saga,
# 98          111       1,169         13   (The Men of Space Station One,
# 99        3,244       1,155         16                              NaN
#
#     series_no
# 0         NaN
# 1          #1
# 2         NaN
# 3          #1
# 4         NaN
# 5          #1
# 6          #2
# 7          #1
# 8         NaN
# 9         NaN
# 10         #1
# 11         #3
# 12        NaN
# 13         #1
# 14        NaN
# 15         #1
# 16         #1
# 17         #1
# 18         #1
# 19         #1
# 20         #2
# 21         #2
# 22         #7
# 23         #1
# 24         #2
# 25        NaN
# 26        #10
# 27         #1
# 28         #1
# 29         #2
# ..        ...
# 70  #6609, #4
# 71        NaN
# 72  #6609, #1
# 73        NaN
# 74         #1
# 75        NaN
# 76  #6609, #5
# 77         #2
# 78        #14
# 79         #1
# 80  #6609, #6
# 81         #1
# 82  #6609, #2
# 83        #10
# 84         #1
# 85         #2
# 86         #2
# 87        NaN
# 88        NaN
# 89        NaN
# 90         #1
# 91        NaN
# 92         #1
# 93         #5
# 94         #3
# 95         #2
# 96         #1
# 97         #1
# 98         #4
# 99        NaN
#
# [100 rows x 11 columns]

# %% [markdown]
# ## 1.3 Where you're just doing one of my former students' projects
#
# Once upon a time my student Stefan did a project that involved some lawyer stuff. Most of the content was in PDFs, though! I converted them to text files and put them into the `pdfs` folder, and gave you code below to open up each of them and save their contents into a dataframe.
#
# What a nice dataframe! I want you to add the following columns to it:
#
# * `lawyer_app`, the applicant's lawyer (pro se means that they did it themselves, that's fine)
# * `lawyer_gov`, the government's lawyer
# * `judge`, the name of the judge
# * `access`, whether the clearance is granted or denied (although you might miss a few)
#
# Save as **court_cleaned.csv**.
#
# **Note:** You can look at the original PDFs, they're also included.
#
# **Note:** This uses a fun utility called `glob`, which is mostly fun because you use it as `glob.glob`. It's used to find files that match a certain filename pattern.
#
# **BONUS:** You'll be happy once you get the judge, but make sure it doesn't have any extra punctuation on it.
#
# **BONUS:** You can for some words using `.str.contains("blah")` and save it into new columns. Maybe `has_debt`, `has_bankruptcy`, etc.
#
# > It's okay if it isn't perfect. Converting PDF into data rarely is! Usually you get 90% of it done with computers, then send people to enter the other 10% by hand.

# %%
import glob
filenames = glob.glob("pdfs/*.txt")
contents = [open(filename, encoding="utf8").read() for filename in filenames]
df = pd.DataFrame({'filename': filenames, 'content': contents})

# %%
df.head()
# Out:
#                    filename  \
# 0  pdfs/11-11916.h1.pdf.txt
# 1  pdfs/12-01601.a1.pdf.txt
# 2  pdfs/11-03073.h1.pdf.txt
# 3  pdfs/11-04909.h1.pdf.txt
# 4  pdfs/11-08313.h1.pdf.txt
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                content
# 0                                                                \n\nDEPARTMENT OF DEFENSE \n\nDEFENSE OFFICE OF HEARINGS AND APPEALS \n\n           \n             \n\n \n \nIn the matter of: \n \n \n \nApplicant for Security Clearance \n\nREDACTED \n\n \n\nISCR Case No. 11-11916 \n\nMENDEZ, Francisco, Administrative Judge: \n\n \nApplicant  did  not  mitigate  security  concerns  raised  by  his  exercise  of  foreign \ncitizenship,  including  the  possession  of  a  current  foreign  passpor...
# 1  KEYWORD: Guideline F\n\nDIGEST: Most of the document Applicant submitted on appeal were not previously submitted to\nthe Judge and the Board is prohibited from receiving or considering them.  Adverse decision\naffirmed.\n\nCASENO: 12-01601.a1\n\nDATE: 09/23/2016\n\nIn Re:\n\n-------\n\nApplicant for Security Clearance\n\nDATE: September 23, 2016\n\nISCR Case No. 12-01601\n\n)\n)\n)\n)\n)\n)\n)\n)\n\nAPPEAL BOARD DECISION\n\nAPPEARANCES\n\nFOR GOVERNMENT\n\nJames B. Norman, Esq., Chief Depart...
# 2                                                                \n\n                        DEPARTMENT OF DEFENSE \n\n         DEFENSE OFFICE OF HEARINGS AND APPEALS \n\n \n \nIn the matter of: \n \n \n \nApplicant for Security Clearance \n\n \n\n \n\nISCR Case No. 11-03073 \n\n           \n             \n\n) \n) \n) \n) \n) \n \n \n\n \n \n\nAppearances \n\n______________ \n\n \nDecision \n\n______________ \n\n \n\n \n\n \n\n \n \n\nFor Government: Robert J. Kilmartin, Esq., Department Counse...
# 3                                                                \n\n            DEFENSE OFFICE OF HEARINGS AND APPEALS \n\n    DEPARTMENT OF DEFENSE \n\n          \n             \n\n \n\n \nIn the matter of: \n \n \n \nApplicant for Security Clearance \n\n \n \n\n \n\nISCR Case No. 11-04909 \n\n \n\nFor Government: Richard Stevens, Esq., Department Counsel \n\nFor Applicant: Pro se \n\n \n\n \nDUFFY, James F., Administrative Judge: \n\n \nApplicant  mitigated \n\nconsiderations). Clearance is ...
# 4                                                              \n\n                           DEPARTMENT OF DEFENSE \n         DEFENSE OFFICE OF HEARINGS AND APPEALS \n\n \n\nISCR Case No. 11-08313 \n\n \nIn the matter of: \n \n \n \nApplicant for Security Clearance \n\n--------------- \n \n\n \n\n           \n             \n\n) \n) \n) \n) \n) \n \n\n \n \n\nAppearances \n\n______________ \n\n \nDecision \n\n______________ \n\nFor Government: Julie R. Mendez, Esquire, Department Counsel \n\nFo...

# %% [markdown]
# Okay, now do the work and **make those new columns!**

# %%
df['lawyer_app'] = df.content.str.extract("(For Applicant: .*)", re.IGNORECASE)
df['lawyer_gov'] = df.content.str.extract("(For Government: .*)", re.IGNORECASE)
df['judge'] = df.content.str.extract("(.* Judge)", re.IGNORECASE)
df['access'] = df.content.str.extract("(access to classified information is .*)")

# %%
df
# Out:
#                     filename  \
# 0   pdfs/11-11916.h1.pdf.txt
# 1   pdfs/12-01601.a1.pdf.txt
# 2   pdfs/11-03073.h1.pdf.txt
# 3   pdfs/11-04909.h1.pdf.txt
# 4   pdfs/11-08313.h1.pdf.txt
# 5   pdfs/12-01969.h1.pdf.txt
# 6   pdfs/11-02438.h1.pdf.txt
# 7   pdfs/11-14135.h1.pdf.txt
# 8   pdfs/11-12635.h1.pdf.txt
# 9   pdfs/12-00038.h1.pdf.txt
# 10  pdfs/11-14832.h1.pdf.txt
# 11  pdfs/11-12537.a1.pdf.txt
# 12  pdfs/12-01601.h1.pdf.txt
# 13  pdfs/11-07728.h1.pdf.txt
# 14  pdfs/12-01787.h1.pdf.txt
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 content  \
# 0                                                                 \n\nDEPARTMENT OF DEFENSE \n\nDEFENSE OFFICE OF HEARINGS AND APPEALS \n\n           \n             \n\n \n \nIn the matter of: \n \n \n \nApplicant for Security Clearance \n\nREDACTED \n\n \n\nISCR Case No. 11-11916 \n\nMENDEZ, Francisco, Administrative Judge: \n\n \nApplicant  did  not  mitigate  security  concerns  raised  by  his  exercise  of  foreign \ncitizenship,  including  the  possession  of  a  current  foreign  passpor...
# 1   KEYWORD: Guideline F\n\nDIGEST: Most of the document Applicant submitted on appeal were not previously submitted to\nthe Judge and the Board is prohibited from receiving or considering them.  Adverse decision\naffirmed.\n\nCASENO: 12-01601.a1\n\nDATE: 09/23/2016\n\nIn Re:\n\n-------\n\nApplicant for Security Clearance\n\nDATE: September 23, 2016\n\nISCR Case No. 12-01601\n\n)\n)\n)\n)\n)\n)\n)\n)\n\nAPPEAL BOARD DECISION\n\nAPPEARANCES\n\nFOR GOVERNMENT\n\nJames B. Norman, Esq., Chief Depart...
# 2                                                                 \n\n                        DEPARTMENT OF DEFENSE \n\n         DEFENSE OFFICE OF HEARINGS AND APPEALS \n\n \n \nIn the matter of: \n \n \n \nApplicant for Security Clearance \n\n \n\n \n\nISCR Case No. 11-03073 \n\n           \n             \n\n) \n) \n) \n) \n) \n \n \n\n \n \n\nAppearances \n\n______________ \n\n \nDecision \n\n______________ \n\n \n\n \n\n \n\n \n \n\nFor Government: Robert J. Kilmartin, Esq., Department Counse...
# 3                                                                 \n\n            DEFENSE OFFICE OF HEARINGS AND APPEALS \n\n    DEPARTMENT OF DEFENSE \n\n          \n             \n\n \n\n \nIn the matter of: \n \n \n \nApplicant for Security Clearance \n\n \n \n\n \n\nISCR Case No. 11-04909 \n\n \n\nFor Government: Richard Stevens, Esq., Department Counsel \n\nFor Applicant: Pro se \n\n \n\n \nDUFFY, James F., Administrative Judge: \n\n \nApplicant  mitigated \n\nconsiderations). Clearance is ...
# 4                                                               \n\n                           DEPARTMENT OF DEFENSE \n         DEFENSE OFFICE OF HEARINGS AND APPEALS \n\n \n\nISCR Case No. 11-08313 \n\n \nIn the matter of: \n \n \n \nApplicant for Security Clearance \n\n--------------- \n \n\n \n\n           \n             \n\n) \n) \n) \n) \n) \n \n\n \n \n\nAppearances \n\n______________ \n\n \nDecision \n\n______________ \n\nFor Government: Julie R. Mendez, Esquire, Department Counsel \n\nFo...
# 5                                                                 \n\n            DEFENSE OFFICE OF HEARINGS AND APPEALS \n\n    DEPARTMENT OF DEFENSE \n\n          \n             \n\n \n\n \n \nIn the matter of: \n\n----------------------------- \n \n\nApplicant for Security Clearance \n\n) \n) \n) \n) \n) \n) \n \n \n\n      ISCR Case No. 12-01969 \n\nAppearances \n\nFor Government: David F. Hayes, Esquire, Department Counsel \n\nFor Applicant: Pro se \n\n \n \n\n______________ \n\n \n\nDecisi...
# 6                                                                 \n\n                           DEPARTMENT OF DEFENSE \n         DEFENSE OFFICE OF HEARINGS AND APPEALS \n\n           \n             \n\n \n \nIn the matter of: \n \n \n \n \nApplicant for Security Clearance \n\n \n \n\n \n\nISCR Case No. 11-02438 \n\nFor Government: Stephanie C. Hess, Esq., Department Counsel \n\nFor Applicant: Pro se \n\nAppearances \n\n______________ \n\n \nDecision \n\n______________ \n\n \n\n \n\n \n\n \n \n\...
# 7                                                                 \n\n            DEFENSE OFFICE OF HEARINGS AND APPEALS \n\n    DEPARTMENT OF DEFENSE \n\n          \n             \n\n \n\n \nIn the matter of: \n \n \n \nApplicant for Security Clearance \n\n \n \n\n \n\nISCR Case No. 11-14135 \n\nAppearances \n\nFor Government: Tara Karoian, Esq., Department Counsel \n\nFor Applicant: Pro se \n\n \n\n \n\n) \n) \n) \n) \n) \n \n \n\n \n \n \n\n \n\n \n\n \n1 \n \n \n\n__________ \n\n \nDecision ...
# 8        DEPARTMENT OF DEFENSE \n\nDEFENSE OFFICE OF HEARINGS AND APPEALS \n\n \n \n \nIn the matter of: \n \n \n \nApplicant for Security Clearance \n \n\n---  \n \n\n           \n             \n\n) \n) \n) \n) \n) \n \n \n\n \n\nISCR Case No. 11-12635 \n\nAppearances \n\nFor Government: Richard Stevens, Esquire, Department Counsel \n\nFor Applicant: Ryan C. Nerney, Esquire \n\n \n \n\n______________ \n\n \n\nDecision \n\n______________ \n\n \n\n \n\n \n \n\nGALES, Robert Robinson, Administrati...
# 9                                                                 \n\n                           DEPARTMENT OF DEFENSE \n\n            DEFENSE OFFICE OF HEARINGS AND APPEALS \n\n           \n             \n\n \n \nIn the matter of: \n \n \n \n \nApplicant for Security Clearance \n\n \n \n\n) \n) \n) \n) \n) \n) \n \n \n\n \n \n\nISCR Case No. 12-00038 \n \n\nAppearances \n\nFor Government: Robert Kilmartin, Esq., Department Counsel \n\nFor Applicant: Pro Se \n\n \n\nApril 28, 2017 \n\n__________...
# 10                                                               \n\n                           DEPARTMENT OF DEFENSE \n         DEFENSE OFFICE OF HEARINGS AND APPEALS \n\n           \n             \n\n \nIn the matter of: \n \n[Name Redacted] \n \n \nApplicant for Security Clearance \n\n \n\n) \n) \n) \n) \n) \n) \n \n \n\n \n\nISCR Case No. 11-14832 \n\nAppearances \n\nFor Government: Eric Borgstrom, Esquire, Department Counsel \n\nFor Applicant: Pro se \n\n \n\n______________ \n\n \n\nDecisio...
# 11  KEYWORD: Guideline F\n\nDIGEST: Applicant’s concern regarding the malfunction of video-teleconference equipment is\novercome by the Judge’s express statement that he did not consider those pages of the transcript. \nAdverse decision affirmed.\n\nCASENO: 11-12537.a1\n\nDATE: 02/11/2016\n\nIn Re:\n\n----------\n \n\nApplicant for Security Clearance\n\nDATE: February 11, 2016\n\nISCR Case No. 11-12537\n\n)\n)\n)\n)\n)\n)\n)\n)\n\nAPPEAL BOARD DECISION\n\nAPPEARANCES\n\nFOR GOVERNMENT\n\nJames B...
# 12          MOGUL, Martin H., Administrative Judge
# 13              HARVEY, Mark, Administrative Judge
# 14      GARCIA, Candace Le’i, Administrative Judge
#
#                                             access
# 0                                              NaN
# 1                                              NaN
# 2   access to classified information is granted.
# 3                                              NaN
# 4     access to classified information is denied.
# 5     access to classified information is denied.
# 6    access to classified information is denied.
# 7     access to classified information is denied.
# 8    access to classified information is granted.
# 9    access to classified information is denied.
# 10   access to classified information is granted.
# 11                                             NaN
# 12     access to classified information is denied.
# 13  access to classified information is granted.
# 14  access to classified information is granted.

# %% [markdown]
# # Reading books
#
# When you're doing text work, you're legally obligated work on Jane Austen's Pride and Prejudice (at least I *think* so). Let's do some naive analysis of it!
#
# ## Read in Jane Austen's Pride and Prejudice (without moving the file!)
#
# It's in the `data/` directory, and named `Austen_Pride.txt`.

# %%
contents = open("data/Austen_Pride.txt").read()

# %% [markdown]
# ## Look at the first 500 or so characters of it

# %%
contents[:500]
# Out:
# ' Pride and Prejudice\nby Jane Austen\nChapter 1\nIt is a truth universally acknowledged, that a single man in possession of a good fortune, must be in want of a wife.\nHowever little known the feelings or views of such a man may be on his first entering a neighbourhood, this truth is so well fixed in the minds of the surrounding families, that he is considered the rightful property of some one or other of their daughters.\n"My dear Mr. Bennet," said his lady to him one day, "have you heard that Nethe'

# %% [markdown]
# ## Use a regular expression to find every "he" or "she" in the book. There should be about 3000 of them.
#
# **Tip:** Do you know about **word boundaries?** `\b` means "the beginning of end of a word."
#
# **Tip:** You might also want to use `re.IGNORECASE`. Maybe you'll need to google it?
#
# **Tip:** Do NOT use `re.compile`

# %%
matches = re.findall(r"\bs*he\b", contents, re.IGNORECASE)
matches
# Out:
# ['he',
#  'he',
#  'she',
#  'she',
#  'he',
#  'he',
#  'he',
#  'he',
#  'he',
#  'he',
#  'she',
#  'he',
#  'he',
#  'she',
#  'he',
#  'She',
#  'she',
#  'she',
#  'He',
#  'he',
#  'she',
#  'he',
#  'She',
#  'She',
#  'she',
#  'she',
#  'she',
#  'he',
#  'he',
#  'he',
#  'she',
#  'she',
#  'he',
#  'he',
#  'she',
#  'he',
#  'he',
#  'He',
#  'he',
#  'He',
#  'he',
#  'he',
#  'he',
#  'She',
#  'he',
#  'she',
#  'he',
#  'he',
#  'he',
#  'he',
#  'he',
#  'he',
#  'he',
#  'he',
#  'He',
#  'he',
#  'he',
#  'She',
#  'he',
#  'he',
#  'She',
#  'She',
#  'she',
#  'she',
#  'he',
#  'he',
#  'He',
#  'he',
#  'he',
#  'she',
#  'she',
#  'he',
#  'she',
#  'he',
#  'he',
#  'he',
#  'he',
#  'she',
#  'he',
#  'she',
#  'he',
#  'he',
#  'he',
#  'he',
#  'He',
#  'she',
#  'She',
#  'she',
#  'he',
#  'He',
#  'he',
#  'she',
#  'He',
#  'she',
#  'He',
#  'he',
#  'He',
#  'he',
#  'she',
#  'he',
#  'he',
#  'he',
#  'he',
#  'He',
#  'he',
#  'He',
#  'he',
#  'he',
#  'he',
#  'he',
#  'he',
#  'she',
#  'he',
#  'he',
#  'he',
#  'he',
#  'he',
#  'he',
#  'he',
#  'he',
#  'he',
#  'he',
#  'he',
#  'he',
#  'he',
#  'he',
#  'he',
#  'she',
#  'he',
#  'he',
#  'she',
#  'he',
#  'he',
#  'he',
#  'he',
#  'he',
#  'he',
#  'he',
#  'he',
#  'he',
#  'he',
#  'she',
#  'she',
#  'she',
#  'he',
#  'she',
#  'she',
#  'She',
#  'she',
#  'she',
#  'he',
#  'she',
#  'she',
#  'he',
#  'he',
#  'he',
#  'he',
#  'he',
#  'she',
#  'she',
#  'she',
#  'she',
#  'she',
#  'She',
#  'She',
#  'she',
#  'she',
#  'she',
#  'he',
#  'she',
#  'she',
#  'she',
#  'she',
#  'he',
#  'he',
#  'he',
#  'she',
#  'he',
#  'he',
#  'he',
#  'he',
#  'she',
#  'he',
#  'He',
#  'she',
#  'he',
#  'he',
#  'He',
#  'she',
#  'she',
#  'she',
#  'she',
#  'she',
#  'she',
#  'he',
#  'He',
#  'he',
#  'he',
#  'she',
#  'he',
#  'He',
#  'he',
#  'he',
#  'she',
#  'she',
#  'He',
#  'she',
#  'She',
#  'he',
#  'she',
#  'she',
#  'he',
#  'She',
#  'she',
#  'she',
#  'She',
#  'she',
#  'she',
#  'She',
#  'he',
#  'She',
#  'she',
#  'She',
#  'she',
#  'She',
#  'she',
#  'she',
#  'she',
#  'she',
#  'she',
#  'she',
#  'she',
#  'she',
#  'she',
#  'she',
#  'She',
#  'he',
#  'he',
#  'she',
#  'she',
#  'she',
#  'She',
#  'She',
#  'She',
#  'she',
#  'she',
#  'she',
#  'he',
#  'she',
#  'she',
#  'She',
#  'she',
#  'she',
#  'she',
#  'she',
#  'she',
#  'she',
#  'he',
#  'She',
#  'He',
#  'she',
#  'he',
#  'she',
#  'she',
#  'she',
#  'She',
#  'she',
#  'she',
#  'she',
#  'she',
#  'she',
#  'she',
#  'she',
#  'he',
#  'she',
#  'she',
#  'she',
#  'she',
#  'She',
#  'she',
#  'She',
#  'she',
#  'she',
#  'she',
#  'she',
#  'he',
#  'he',
#  'she',
#  'he',
#  'He',
#  'she',
#  'he',
#  'He',
#  'she',
#  'she',
#  'she',
#  'She',
#  'she',
#  'she',
#  'he',
#  'he',
#  'he',
#  'he',
#  'She',
#  'She',
#  'She',
#  'She',
#  'he',
#  'she',
#  'she',
#  'he',
#  'He',
#  'He',
#  'he',
#  'He',
#  'He',
#  'he',
#  'he',
#  'he',
#  'she',
#  'he',
#  'he',
#  'he',
#  'she',
#  'she',
#  'She',
#  'she',
#  'he',
#  'he',
#  'She',
#  'she',
#  'She',
#  'She',
#  'He',
#  'she',
#  'he',
#  'He',
#  'he',
#  'She',
#  'she',
#  'she',
#  'She',
#  'she',
#  'she',
#  'she',
#  'he',
#  'He',
#  'he',
#  'He',
#  'she',
#  'she',
#  'she',
#  'He',
#  'She',
#  'She',
#  'she',
#  'She',
#  'he',
#  'she',
#  'she',
#  'She',
#  'she',
#  'he',
#  'he',
#  'she',
#  'she',
#  'she',
#  'she',
#  'He',
#  'He',
#  'he',
#  'he',
#  'he',
#  'She',
#  'she',
#  'he',
#  'he',
#  'she',
#  'he',
#  'he',
#  'He',
#  'he',
#  'she',
#  'He',
#  'she',
#  'she',
#  'she',
#  'she',
#  'she',
#  'she',
#  'she',
#  'She',
#  'he',
#  'He',
#  'he',
#  'he',
#  'she',
#  'he',
#  'she',
#  'he',
#  'he',
#  'he',
#  'she',
#  'he',
#  'he',
#  'he',
#  'He',
#  'he',
#  'he',
#  'he',
#  'he',
#  'He',
#  'she',
#  'he',
#  'he',
#  'he',
#  'he',
#  'she',
#  'He',
#  'He',
#  'he',
#  'he',
#  'he',
#  'He',
#  'he',
#  'he',
#  'He',
#  'she',
#  'he',
#  'he',
#  'he',
#  'he',
#  'he',
#  'he',
#  'he',
#  'She',
#  'he',
#  'She',
#  'he',
#  'he',
#  'She',
#  'she',
#  'she',
#  'She',
#  'he',
#  'he',
#  'she',
#  'he',
#  'she',
#  'she',
#  'she',
#  'she',
#  'She',
#  'she',
#  'she',
#  'she',
#  'She',
#  'She',
#  'she',
#  'she',
#  'she',
#  'he',
#  'he',
#  'he',
#  'he',
#  'he',
#  'he',
#  'he',
#  'she',
#  'he',
#  'he',
#  'he',
#  'he',
#  'he',
#  'he',
#  'he',
#  'he',
#  'he',
#  'he',
#  'he',
#  'he',
#  'he',
#  'she',
#  'he',
#  'she',
#  'she',
#  'she',
#  'she',
#  'she',
#  'she',
#  'she',
#  'he',
#  'he',
#  'he',
#  'he',
#  'he',
#  'he',
#  'he',
#  'he',
#  'He',
#  'he',
#  'she',
#  'she',
#  'she',
#  'She',
#  'he',
#  'he',
#  'she',
#  'he',
#  'She',
#  'she',
#  'he',
#  'she',
#  'she',
#  'He',
#  'he',
#  'she',
#  'he',
#  'he',
#  'he',
#  'he',
#  'he',
#  'she',
#  'she',
#  'he',
#  'he',
#  'she',
#  'she',
#  'she',
#  'he',
#  'he',
#  'he',
#  'he',
#  'he',
#  'he',
#  'he',
#  'she',
#  'she',
#  'she',
#  'she',
#  'she',
#  'She',
#  'He',
#  'He',
#  'He',
#  'he',
#  'he',
#  'he',
#  'he',
#  'he',
#  'he',
#  'he',
#  'he',
#  'he',
#  'He',
#  'He',
#  'he',
#  'he',
#  'He',
#  'he',
#  'he',
#  'she',
#  'He',
#  'she',
#  'She',
#  'she',
#  'he',
#  'He',
#  'he',
#  'he',
#  'he',
#  'He',
#  'He',
#  'she',
#  'she',
#  'she',
#  'She',
#  'He',
#  'He',
#  'he',
#  'He',
#  'He',
#  'he',
#  'he',
#  'he',
#  'he',
#  'he',
#  'he',
#  'he',
#  'she',
#  'he',
#  'he',
#  'she',
#  'he',
#  'she',
#  'she',
#  'she',
#  'he',
#  'she',
#  'he',
#  'she',
#  'She',
#  'she',
#  'he',
#  'he',
#  'he',
#  'She',
#  'he',
#  'she',
#  'she',
#  'he',
#  'he',
#  'he',
#  'she',
#  'she',
#  'he',
#  'he',
#  'she',
#  'he',
#  'she',
#  'she',
#  'she',
#  'she',
#  'he',
#  'he',
#  'he',
#  'she',
#  'he',
#  'he',
#  'She',
#  'she',
#  'She',
#  'she',
#  'she',
#  'he',
#  'She',
#  'he',
#  'she',
#  'he',
#  'She',
#  'she',
#  'she',
#  'she',
#  'She',
#  'he',
#  'she',
#  'she',
#  'she',
#  'she',
#  'He',
#  'she',
#  'she',
#  'she',
#  'she',
#  'He',
#  'she',
#  'He',
#  'she',
#  'he',
#  'He',
#  'he',
#  'she',
#  'She',
#  'he',
#  'he',
#  'He',
#  'he',
#  'he',
#  'he',
#  'he',
#  'he',
#  'she',
#  'she',
#  'he',
#  'she',
#  'She',
#  'he',
#  'he',
#  'She',
#  'he',
#  'he',
#  'he',
#  'he',
#  'he',
#  'he',
#  'he',
#  'he',
#  'She',
#  'she',
#  'she',
#  'he',
#  'he',
#  'he',
#  'he',
#  'he',
#  'he',
#  'He',
#  'he',
#  'he',
#  'he',
#  'She',
#  'she',
#  'he',
#  'he',
#  'he',
#  'she',
#  'he',
#  'she',
#  'she',
#  'she',
#  'he',
#  'he',
#  'He',
#  'he',
#  'she',
#  'she',
#  'She',
#  'she',
#  'she',
#  'she',
#  'she',
#  'she',
#  'she',
#  'she',
#  'she',
#  'she',
#  'She',
#  'she',
#  'he',
#  'she',
#  'She',
#  'she',
#  'he',
#  'she',
#  'she',
#  'she',
#  'she',
#  'she',
#  'she',
#  'she',
#  'She',
#  'she',
#  'She',
#  'She',
#  'He',
#  'he',
#  'He',
#  'he',
#  'he',
#  'he',
#  'he',
#  'he',
#  'she',
#  'he',
#  'she',
#  'She',
#  'he',
#  'she',
#  'He',
#  'he',
#  'he',
#  'She',
#  'She',
#  'he',
#  'She',
#  'he',
#  'he',
#  'he',
#  'she',
#  'she',
#  'he',
#  'he',
#  'he',
#  'she',
#  'she',
#  'He',
#  'she',
#  'she',
#  'she',
#  'he',
#  'he',
#  'she',
#  'she',
#  'she',
#  'he',
#  'she',
#  'she',
#  'she',
#  'he',
#  'he',
#  'she',
#  'he',
#  'he',
#  'she',
#  'she',
#  'she',
#  'She',
#  'she',
#  'she',
#  'she',
#  'she',
#  'she',
#  'She',
#  'she',
#  'she',
#  'she',
#  'he',
#  'she',
#  'he',
#  'she',
#  'she',
#  'he',
#  'She',
#  'she',
#  'she',
#  'She',
#  'She',
#  'He',
#  'he',
#  'She',
#  'she',
#  'she',
#  'she',
#  'she',
#  'she',
#  'She',
#  'she',
#  'she',
#  'he',
#  'he',
#  'He',
#  'he',
#  'He',
#  'he',
#  'He',
#  'he',
#  'he',
#  'She',
#  'he',
#  'she',
#  'she',
#  'he',
#  'he',
#  'she',
#  'She',
#  'she',
#  'she',
#  'she',
#  'she',
#  'he',
#  'he',
#  'he',
#  'he',
#  'he',
#  'He',
#  'she',
#  'he',
#  'she',
#  'she',
#  'she',
#  'she',
#  'She',
#  'he',
#  'She',
#  'she',
#  'she',
#  'she',
#  'she',
#  'he',
#  'he',
#  'he',
#  'she',
#  'he',
#  'she',
#  'She',
#  'she',
#  'she',
#  'she',
#  'she',
#  'he',
#  'she',
#  'she',
#  'she',
#  'he',
#  'she',
#  'He',
#  'he',
#  'he',
#  'he',
#  'she',
#  'he',
#  'he',
#  'he',
#  'She',
#  'he',
#  'she',
#  'she',
#  'she',
#  'She',
#  'he',
#  'he',
#  'he',
#  'he',
#  'he',
#  'he',
#  'he',
#  'She',
#  'she',
#  'he',
#  'she',
#  'she',
#  'she',
#  'she',
#  'he',
#  'she',
#  'she',
#  'she',
#  'She',
#  'she',
#  'she',
#  'she',
#  'she',
#  'she',
#  'he',
#  'he',
#  'he',
#  'he',
#  'she',
#  'he',
#  'she',
#  'she',
#  'she',
#  'she',
#  'she',
#  'she',
#  'she',
#  'she',
#  'he',
#  'he',
#  'he',
#  'he',
#  'she',
#  'she',
#  'she',
#  'she',
#  'she',
#  'she',
#  'he',
#  'he',
#  'he',
#  'he',
#  'she',
#  'he',
#  'she',
#  'he',
#  'She',
#  'she',
#  'she',
#  'she',
#  'she',
#  'she',
#  'she',
#  'she',
#  'he',
#  'she',
#  'He',
#  'he',
#  'she',
#  'she',
#  'she',
#  'she',
#  'she',
#  'She',
#  'she',
#  'she',
#  'he',
#  'he',
#  'she',
#  'She',
#  'she',
#  'he',
#  'she',
#  'she',
#  'she',
#  'she',
#  'he',
#  'he',
#  'she',
#  'he',
#  'She',
#  'he',
#  'she',
#  'She',
#  'she',
#  'He',
#  'He',
#  'she',
#  'she',
#  'she',
#  'he',
#  ...]

# %% [markdown]
# ## Use a regular expression to find those same "he" or "she"s, but also match *the word after it*
#
# The first four should be:
#
# * he is
# * he had
# * she told
# * he came

# %%
matches = re.findall(r"\bs*he\b \w+", contents)
matches
# Out:
# ['he is',
#  'he had',
#  'she told',
#  'he came',
#  'he agreed',
#  'he is',
#  'he married',
#  'he may',
#  'he comes',
#  'she ought',
#  'he comes',
#  'he chooses',
#  'she is',
#  'she was',
#  'she fancied',
#  'he should',
#  'she had',
#  'he suddenly',
#  'she times',
#  'she will',
#  'she will',
#  'he continued',
#  'he wished',
#  'she began',
#  'she had',
#  'he spoke',
#  'he left',
#  'he would',
#  'he eluded',
#  'he meant',
#  'he had',
#  'he saw',
#  'he wore',
#  'he could',
#  'she began',
#  'he might',
#  'he ought',
#  'he brought',
#  'he had',
#  'he was',
#  'he was',
#  'he was',
#  'he was',
#  'he would',
#  'he looked',
#  'he withdrew',
#  'she had',
#  'she had',
#  'he was',
#  'he had',
#  'he had',
#  'she entered',
#  'she looked',
#  'he actually',
#  'she was',
#  'he asked',
#  'he asked',
#  'he did',
#  'he seemed',
#  'she was',
#  'he inquired',
#  'she was',
#  'he danced',
#  'he had',
#  'he would',
#  'he had',
#  'she was',
#  'she added',
#  'he is',
#  'he walked',
#  'she admired',
#  'he possibly',
#  'he certainly',
#  'she was',
#  'he was',
#  'he might',
#  'he was',
#  'he was',
#  'he never',
#  'he appeared',
#  'he had',
#  'he could',
#  'he had',
#  'he acknowledged',
#  'she smiled',
#  'he chose',
#  'he had',
#  'he had',
#  'he could',
#  'he was',
#  'he seemed',
#  'he danced',
#  'he admired',
#  'he _did_',
#  'he liked',
#  'he did',
#  'he thought',
#  'he is',
#  'he sat',
#  'she asked',
#  'he liked',
#  'he could',
#  'she said',
#  'he seemed',
#  'he never',
#  'he is',
#  'he had',
#  'he would',
#  'he is',
#  'he had',
#  'he had',
#  'he has',
#  'he had',
#  'she should',
#  'she continued',
#  'she would',
#  'he did',
#  'she had',
#  'she considered',
#  'she may',
#  'she feels',
#  'he may',
#  'she does',
#  'she does',
#  'he must',
#  'he does',
#  'he must',
#  'he must',
#  'he sees',
#  'she can',
#  'she is',
#  'she chooses',
#  'she is',
#  'she cannot',
#  'she saw',
#  'she merely',
#  'she might',
#  'he had',
#  'she were',
#  'she had',
#  'she were',
#  'she was',
#  'he had',
#  'he looked',
#  'he made',
#  'she hardly',
#  'he began',
#  'he had',
#  'he was',
#  'he was',
#  'she was',
#  'he was',
#  'she to',
#  'he does',
#  'he is',
#  'she turned',
#  'she added',
#  'she could',
#  'she would',
#  'she was',
#  'she had',
#  'he continued',
#  'he was',
#  'he would',
#  'she instantly',
#  'he can',
#  'he was',
#  'he would',
#  'she been',
#  'she will',
#  'she chose',
#  'he was',
#  'she sees',
#  'she was',
#  'he say',
#  'she was',
#  'she should',
#  'she stays',
#  'she was',
#  'he goes',
#  'she should',
#  'she longed',
#  'she was',
#  'she saw',
#  'she had',
#  'she must',
#  'she only',
#  'she had',
#  'she could',
#  'she could',
#  'she believed',
#  'she was',
#  'he was',
#  'he found',
#  'she returned',
#  'she was',
#  'she had',
#  'she be',
#  'she came',
#  'she mean',
#  'he replied',
#  'she is',
#  'she were',
#  'she had',
#  'she should',
#  'she found',
#  'she declined',
#  'she would',
#  'she could',
#  'she could',
#  'he replied',
#  'she drew',
#  'she be',
#  'she will',
#  'she was',
#  'she must',
#  'she must',
#  'she must',
#  'she could',
#  'she would',
#  'she was',
#  'he could',
#  'she very',
#  'she requested',
#  'she found',
#  'she had',
#  'she expected',
#  'she remains',
#  'she added',
#  'she is',
#  'she has',
#  'she had',
#  'he replied',
#  'she called',
#  'she would',
#  'she was',
#  'she is',
#  'she is',
#  'she was',
#  'he would',
#  'he did',
#  'he thought',
#  'he wrote',
#  'he did',
#  'she is',
#  'she added',
#  'he does',
#  'he does',
#  'he did',
#  'he would',
#  'he has',
#  'she could',
#  'he was',
#  'he had',
#  'he applied',
#  'she seated',
#  'she turned',
#  'she could',
#  'he should',
#  'he disliked',
#  'she drew',
#  'he was',
#  'he should',
#  'she left',
#  'she rambled',
#  'she was',
#  'she had',
#  'he had',
#  'he was',
#  'she should',
#  'she removed',
#  'she might',
#  'she was',
#  'he merely',
#  'she had',
#  'she gave',
#  'she turned',
#  'he may',
#  'he chooses',
#  'she replied',
#  'she got',
#  'she walked',
#  'she resolved',
#  'he declined',
#  'he could',
#  'he mean',
#  'she could',
#  'he means',
#  'she allowed',
#  'he may',
#  'he replied',
#  'she had',
#  'she was',
#  'she could',
#  'she much',
#  'she urged',
#  'she had',
#  'she was',
#  'she felt',
#  'he liked',
#  'he scarcely',
#  'he adhered',
#  'she even',
#  'he had',
#  'she often',
#  'he had',
#  'he thus',
#  'he pleases',
#  'she continued',
#  'he not',
#  'he does',
#  'he folded',
#  'he says',
#  'he is',
#  'he can',
#  'he thinks',
#  'he mean',
#  'he would',
#  'he could',
#  'he be',
#  'she was',
#  'he complimented',
#  'he had',
#  'he did',
#  'he begged',
#  'he was',
#  'she declared',
#  'he continued',
#  'he thought',
#  'he expected',
#  'he seemed',
#  'he protested',
#  'he had',
#  'he had',
#  'he had',
#  'he knew',
#  'he had',
#  'she would',
#  'she made',
#  'he could',
#  'he chose',
#  'she had',
#  'he had',
#  'she is',
#  'she live',
#  'she was',
#  'she any',
#  'she is',
#  'she handsome',
#  'she could',
#  'she is',
#  'she been',
#  'he had',
#  'he listened',
#  'he started',
#  'he never',
#  'he chose',
#  'he opened',
#  'he had',
#  'she interrupted',
#  'he does',
#  'he offered',
#  'he acted',
#  'he would',
#  'he bore',
#  'he belonged',
#  'he had',
#  'he felt',
#  'he intended',
#  'he had',
#  'he meant',
#  'he found',
#  'he thought',
#  'she was',
#  'he had',
#  'she could',
#  'she could',
#  'she did',
#  'she must',
#  'she felt',
#  'she might',
#  'she could',
#  'he would',
#  'he had',
#  'he told',
#  'he was',
#  'he bowed',
#  'he could',
#  'he was',
#  'he had',
#  'he said',
#  'she was',
#  'she should',
#  'she had',
#  'he returned',
#  'he could',
#  'she could',
#  'he was',
#  'she said',
#  'he walked',
#  'she had',
#  'she could',
#  'he had',
#  'she had',
#  'he supposed',
#  'he had',
#  'he was',
#  'he declared',
#  'he might',
#  'she had',
#  'she felt',
#  'he was',
#  'he found',
#  'she heard',
#  'she could',
#  'she had',
#  'he finally',
#  'he immediately',
#  'he certainly',
#  'he had',
#  'he had',
#  'he received',
#  'she was',
#  'she soon',
#  'she was',
#  'she chiefly',
#  'she could',
#  'he or',
#  'he chooses',
#  'he is',
#  'he wishes',
#  'he must',
#  'he is',
#  'he had',
#  'he added',
#  'he had',
#  'he hates',
#  'he will',
#  'he expressed',
#  'she continued',
#  'she contented',
#  'he gave',
#  'he felt',
#  'he should',
#  'he is',
#  'she is',
#  'she was',
#  'she is',
#  'he chooses',
#  'he thinks',
#  'he is',
#  'he is',
#  'he is',
#  'he had',
#  'he assured',
#  'he considered',
#  'she would',
#  'he asked',
#  'she replied',
#  'he certainly',
#  'she is',
#  'she and',
#  'she thought',
#  'he were',
#  'he has',
#  'she is',
#  'she derives',
#  'he had',
#  'he said',
#  'he did',
#  'he had',
#  'she had',
#  'she had',
#  'he did',
#  'he crowded',
#  'he could',
#  'she knew',
#  'he gave',
#  'he had',
#  'she had',
#  'he was',
#  'she had',
#  'she did',
#  'she could',
#  'he intended',
#  'he did',
#  'he would',
#  'she was',
#  'he entertained',
#  'she could',
#  'she was',
#  'she observed',
#  'he did',
#  'he had',
#  'she could',
#  'he directly',
#  'she could',
#  'she had',
#  'she was',
#  'he was',
#  'she returned',
#  'she found',
#  'she did',
#  'she accepted',
#  'she was',
#  'she was',
#  'she began',
#  'she made',
#  'she addressed',
#  'she wished',
#  'he asked',
#  'she and',
#  'he said',
#  'he may',
#  'he is',
#  'he stopped',
#  'he turned',
#  'she replied',
#  'she said',
#  'he gravely',
#  'he coldly',
#  'he was',
#  'he has',
#  'he cannot',
#  'he could',
#  'he was',
#  'he had',
#  'he could',
#  'he informed',
#  'she was',
#  'he will',
#  'he has',
#  'he has',
#  'he never',
#  'he has',
#  'he say',
#  'he has',
#  'he believes',
#  'he is',
#  'she had',
#  'he had',
#  'he will',
#  'she ceased',
#  'he left',
#  'she eagerly',
#  'she could',
#  'she felt',
#  'he only',
#  'he was',
#  'she could',
#  'she turned',
#  'she felt',
#  'she plainly',
#  'she determined',
#  'she might',
#  'she considered',
#  'she vexed',
#  'she could',
#  'she might',
#  'she liked',
#  'she could',
#  'he may',
#  'she could',
#  'she dreaded',
#  'he was',
#  'she was',
#  'she saw',
#  'she had',
#  'she endeavour',
#  'she began',
#  'she watched',
#  'she might',
#  'she bore',
#  'he must',
#  'he cannot',
#  'he should',
#  'he owes',
#  'he concluded',
#  'he was',
#  'she think',
#  'he must',
#  'she could',
#  'he could',
#  'she entreat',
#  'he was',
#  'he should',
#  'he never',
#  'he would',
#  'he readily',
#  'he was',
#  'she should',
#  'she thought',
#  'he set',
#  'he supposed',
#  'he addressed',
#  'she can',
#  'she was',
#  'she added',
#  'she sat',
#  'she could',
#  'he allowed',
#  'he continued',
#  'she condescended',
#  'she said',
#  'she cried',
#  'he first',
#  'she would',
#  'she thus',
#  'she would',
#  'he persisted',
#  'she entered',
#  'he trusted',
#  'he had',
#  'she would',
#  'she dared',
#  'she added',
#  'she is',
#  'she would',
#  'she actually',
#  'she could',
#  'she is',
#  'she entered',
#  'she vows',
#  'she will',
#  'he will',
#  'she entered',
#  'she had',
#  'she will',
#  'he will',
#  'she appeared',
#  'she wished',
#  'he suffered',
#  'she will',
#  'she likewise',
#  'she added',
#  'she comes',
#  'she can',
#  'she said',
#  'she could',
#  'he presently',
#  'he had',
#  'he meant',
#  'he voluntarily',
#  'he particularly',
#  'she felt',
#  'she read',
#  'he and',
#  'he companion',
#  'she says',
#  'she saw',
#  'she was',
#  'she is',
#  'he imagined',
#  'he will',
#  'he may',
#  'he comes',
#  'he should',
#  'she inspires',
#  'he will',
#  'she finished',
#  'she is',
#  'she suspects',
#  'she means',
#  'he does',
#  'she have',
#  'she would',
#  'she is',
#  'she may',
#  'he is',
#  'he took',
#  'he is',
#  'she is',
#  'he returns',
#  'she could',
#  'she felt',
#  'she was',
#  'she bewailed',
#  'she had',
#  'he had',
#  'she would',
#  'she would',
#  'he had',
#  'she did',
#  'he was',
#  'he was',
#  'he walked',
#  'she dared',
#  'he earnestly',
#  'he was',
#  'he and',
#  'he would',
#  'she had',
#  'she felt',
#  'she valued',
#  'he returned',
#  'he was',
#  'he was',
#  'he was',
#  'he replied',
#  'he meditated',
#  'he thought',
#  'she thought',
#  'he might',
#  'she could',
#  'she could',
#  'she expected',
#  'she soon',
#  'he was',
#  'she wished',
#  'she had',
#  'she became',
#  'she had',
#  'she would',
#  'she had',
#  'she had',
#  'she was',
#  'he unfolded',
#  'he must',
#  'he begged',
#  'he listened',
#  'she was',
#  'he left',
#  'she persisted',
#  'she was',
#  'she trusted',
#  'she herself',
#  'she principally',
#  'she could',
#  'she could',
#  'she could',
#  'he did',
#  'he pronounced',
#  'he said',
#  'he had',
#  'she said',
#  'she called',
#  'she was',
#  'she was',
#  'she grew',
#  'she might',
#  'he proceeded',
#  'he had',
#  'he hoped',
#  'he added',
#  'she wished',
#  'he trusted',
#  'she was',
#  'he should',
#  'she never',
#  'she was',
#  'she could',
#  'she feared',
#  'she felt',
#  'she was',
#  'she did',
#  'he did',
#  'she would',
#  'he sometimes',
#  'she went',
#  'she was',
#  'she regarded',
#  'she concluded',
#  'she spoke',
#  'she went',
#  'he have',
#  'he left',
#  'she found',
#  'she paid',
#  'he was',
#  'she doubted',
#  'she had',
#  'she had',
#  'she could',
#  'he might',
#  'he thought',
#  'she thought',
#  'he must',
#  'he had',
#  'she could',
#  'she gives',
#  'she soon',
#  'she is',
#  'she may',
#  'he is',
#  'he is',
#  'he were',
#  'she did',
#  'he saw',
#  'she had',
#  'he one',
#  'he had',
#  'he had',
#  'she had',
#  'she last',
#  'she continued',
#  'she could',
#  'she might',
#  'she refused',
#  'she spoke',
#  'he was',
#  'he was',
#  'he offended',
#  'she may',
#  'she would',
#  'he really',
#  'he is',
#  'he would',
#  'he once',
#  'she felt',
#  'she did',
#  'she thought',
#  'she hoped',
#  'she might',
#  'she saw',
#  'she resolved',
#  'she left',
#  'she had',
#  'he belonged',
#  'she had',
#  'she was',
#  'she tried',
#  'she recollected',
#  'she thought',
#  'she thus',
#  'he is',
#  'he had',
#  'he ought',
#  'he is',
#  'he becomes',
#  'he should',
#  'he is',
#  'he has',
#  'she was',
#  'he took',
#  'she was',
#  'she rose',
#  'she foresaw',
#  'she would',
#  'she would',
#  'she would',
#  'she might',
#  'she could',
#  'she must',
#  'she wrote',
#  'she continued',
#  'she had',
#  'she was',
#  'she did',
#  'she could',
#  'she wrote',
#  'she felt',
#  'she did',
#  'she had',
#  'she made',
#  'she went',
#  'she did',
#  'she must',
#  'she has',
#  'she feels',
#  'he is',
#  'she must',
#  'he had',
#  'she said',
#  'she wanted',
#  'he is',
#  'she considered',
#  'she seriously',
#  'he might',
#  'she would',
#  'he had',
#  'he was',
#  'she could',
#  'she would',
#  'he was',
#  'she was',
#  'she thus',
#  'she soon',
#  'she gradually',
#  'she would',
#  'he told',
#  'she was',
#  'she felt',
#  'she parted',
#  'he must',
#  'she had',
#  'she was',
#  'she was',
#  'she added',
#  'he is',
#  'he is',
#  'he paid',
#  'he did',
#  'she does',
#  'she shall',
#  'she had',
#  'she rapturously',
#  'she had',
#  'she had',
#  'she found',
#  'he detained',
#  'he welcomed',
#  'she could',
#  'he addressed',
#  'she had',
#  'she was',
#  'she could',
#  'she involuntarily',
#  'she could',
#  'he attended',
#  'she encouraged',
#  'he asked',
#  'he must',
#  'she will',
#  'she honours',
#  'she has',
#  'she was',
#  'she heard',
#  'she could',
#  'she not',
#  'she hardly',
#  'she will',
#  'he began',
#  'he had',
#  'he knew',
#  'he said',
#  'he came',
#  'she looked',
#  'she could',
#  'she thought',
#  'she could',
#  'he would',
#  'he had',
#  'she said',
#  'she believed',
#  'he represented',
#  'she soon',
#  'she turned',
#  'she could',
#  'she spoke',
#  'she said',
#  'he had',
#  'he took',
#  'he felt',
#  'she was',
#  'she was',
#  'she did',
#  'she was',
#  'she addressed',
#  'she knew',
#  'she observed',
#  'she had',
#  'she assured',
#  'she is',
#  'he won',
#  'he thought',
#  'he won',
#  'she had',
#  'she made',
#  'he was',
#  'he went',
#  'she soon',
#  'she did',
#  'she gave',
#  'he never',
#  'she could',
#  'she accepted',
#  'she was',
#  'she sallied',
#  'she spent',
#  'she had',
#  'she frequently',
#  'she felt',
#  'she did',
#  'she might',
#  'he was',
#  'he had',
#  'he hastened',
#  'he had',
#  'he never',
#  'she wished',
#  'he would',
#  'she thought',
#  'he looked',
#  'he answered',
#  'he had',
#  'he must',
#  'she could',
#  'she was',
#  'she did',
#  'she would',
#  'she cannot',
#  'she does',
#  'he replied',
#  'she does',
#  'she will',
#  'she practises',
#  'she is',
#  'she sat',
#  'he was',
#  'he replied',
#  ...]

# %% [markdown]
# ## Use capture groups to save the pronoun (he/she) as one match and the word as another
#
# The first five should look like
#
# ```
# [('he', 'is'),
#  ('he', 'had'),
#  ('she', 'told'),
#  ('he', 'came'),
#  ('he', 'agreed')]```

# %%
matches = re.findall(r"(\bs*he\b)( \w+)", contents, re.IGNORECASE)
matches
# Out:
# [('he', ' is'),
#  ('he', ' had'),
#  ('she', ' told'),
#  ('he', ' came'),
#  ('he', ' agreed'),
#  ('he', ' is'),
#  ('he', ' married'),
#  ('he', ' may'),
#  ('he', ' comes'),
#  ('she', ' ought'),
#  ('he', ' comes'),
#  ('he', ' chooses'),
#  ('she', ' is'),
#  ('She', ' was'),
#  ('she', ' was'),
#  ('she', ' fancied'),
#  ('He', ' had'),
#  ('he', ' should'),
#  ('she', ' had'),
#  ('he', ' suddenly'),
#  ('She', ' has'),
#  ('She', ' is'),
#  ('she', ' times'),
#  ('she', ' will'),
#  ('she', ' grew'),
#  ('she', ' might'),
#  ('he', ' proceeded'),
#  ('he', ' had'),
#  ('he', ' hoped'),
#  ('he', ' added'),
#  ('she', ' wished'),
#  ('he', ' trusted'),
#  ('she', ' was'),
#  ('he', ' should'),
#  ('She', ' hated'),
#  ('she', ' never'),
#  ('she', ' was'),
#  ('she', ' could'),
#  ('she', ' feared'),
#  ('she', ' felt'),
#  ('she', ' was'),
#  ('she', ' did'),
#  ('he', ' did'),
#  ('she', ' would'),
#  ('He', ' was'),
#  ('he', ' sometimes'),
#  ('she', ' went'),
#  ('she', ' was'),
#  ('she', ' regarded'),
#  ('she', ' concluded'),
#  ('she', ' spoke'),
#  ('She', ' complained'),
#  ('she', ' went'),
#  ('he', ' have'),
#  ('he', ' left'),
#  ('she', ' found'),
#  ('She', ' wrote'),
#  ('she', ' paid'),
#  ('he', ' was'),
#  ('she', ' doubted'),
#  ('she', ' had'),
#  ('she', ' had'),
#  ('she', ' could'),
#  ('he', ' might'),
#  ('he', ' thought'),
#  ('she', ' thought'),
#  ('he', ' must'),
#  ('She', ' could'),
#  ('he', ' had'),
#  ('she', ' could'),
#  ('She', ' can'),
#  ('she', ' gives'),
#  ('He', ' will'),
#  ('He', ' may'),
#  ('she', ' soon'),
#  ('she', ' is'),
#  ('she', ' may'),
#  ('he', ' is'),
#  ('he', ' is'),
#  ('he', ' were'),
#  ('she', ' did'),
#  ('he', ' saw'),
#  ('she', ' had'),
#  ('he', ' one'),
#  ('He', ' is'),
#  ('he', ' had'),
#  ('he', ' had'),
#  ('He', ' took'),
#  ('she', ' had'),
#  ('she', ' last'),
#  ('she', ' continued'),
#  ('she', ' could'),
#  ('she', ' might'),
#  ('He', ' made'),
#  ('she', ' refused'),
#  ('she', ' spoke'),
#  ('he', ' was'),
#  ('he', ' was'),
#  ('he', ' offended'),
#  ('she', ' may'),
#  ('she', ' would'),
#  ('he', ' really'),
#  ('he', ' is'),
#  ('he', ' would'),
#  ('he', ' once'),
#  ('She', ' will'),
#  ('She', ' will'),
#  ('she', ' felt'),
#  ('she', ' did'),
#  ('she', ' thought'),
#  ('she', ' hoped'),
#  ('she', ' might'),
#  ('she', ' saw'),
#  ('she', ' resolved'),
#  ('she', ' left'),
#  ('she', ' had'),
#  ('he', ' belonged'),
#  ('she', ' had'),
#  ('she', ' was'),
#  ...]

# %% [markdown]
# ## Save those matches into a dataframe
#
# You can give the column names with `columns=['pronoun', 'verb']`

# %%
df = pd.DataFrame(matches, columns=['pronoun','verb'])
df.head()
# Out:
#   pronoun     verb
# 0      he       is
# 1      he      had
# 2     she     told
# 3      he     came
# 4      he   agreed

# %% [markdown]
# ## How many times is each pronoun used?

# %%
df.pronoun.value_counts()
# Out:
# she    1322
# he     1054
# She     325
# He      234
# Name: pronoun, dtype: int64

# %% [markdown]
# ## Oh, wait, clean that up.
#
# Make it only 'he' and 'she' lowercase.
#
# It should be about 1600 'she' and 1300 'he'

# %%
df['pronoun'] = df.pronoun.str.lower()

# %%
df.pronoun.value_counts()
# Out:
# she    1647
# he     1288
# Name: pronoun, dtype: int64

# %% [markdown]
# ## What are the top 20 most common verbs?

# %%
df.verb.value_counts().nlargest(20)
# Out:
#  was          372
#  had          371
#  could        172
#  is           139
#  would         94
#  has           70
#  did           67
#  will          50
#  might         46
#  should        41
#  felt          38
#  must          37
#  said          33
#  saw           32
#  thought       31
#  added         31
#  then          26
#  replied       22
#  continued     21
#  looked        21
# Name: verb, dtype: int64

# %% [markdown]
# ## What are the top 20 most common verbs for 'he', and the top 20 most common for 'she'
#
# **Tip:** Don't use groupby, just filter. If you want to know how, though, you can also look at "value counts for different categories" on [this page](http://jonathansoma.com/lede/foundations-2017/classes/more-pandas/class-notes/)

# %%
df[df['pronoun'] == 'he'].verb.value_counts().head(20)
# Out:
#  had        166
#  was        160
#  is          74
#  has         49
#  could       40
#  would       35
#  did         29
#  should      26
#  must        24
#  will        24
#  might       21
#  replied     14
#  may         13
#  said        13
#  came        13
#  thought     13
#  never       12
#  does        12
#  meant       11
#  then        11
# Name: verb, dtype: int64

# %%
df[df['pronoun'] == 'she'].verb.value_counts().head(20)
# Out:
#  was        212
#  had        205
#  could      132
#  is          65
#  would       59
#  did         38
#  felt        33
#  saw         29
#  will        26
#  might       25
#  added       23
#  has         21
#  said        20
#  thought     18
#  then        15
#  should      15
#  found       13
#  must        13
#  soon        12
#  looked      11
# Name: verb, dtype: int64

# %% [markdown]
# ## Who cries more, men or women? Give me a percentage answer.
#
# **Tip:** It's `cried`, because of, you know, how books are written

# %%
df[df["verb"] == ' cried'].pronoun.value_counts(normalize = True) *100
# Out:
# she    91.666667
# he      8.333333
# Name: pronoun, dtype: float64

# %% [markdown]
# ## How much more common is 'he' than 'she' in J.R.R. Tolkein's Fellowship of the Ring? How does that compare to Pride and Prejudice?
#
# The book is in the same directory.

# %%
contents_lotr = open("data/Lord of the Rings - 01 - The Fellowship of the Ring - J. R. R. Tolkien - 1955.txt").read()

# %%
contents_lotr[:500]
# Out:
# 'THE FELLOWSHIP OF THE RING\n\n\n\n\nBEING THE FIRST PART OF\n\nTHE LORD OF THE RINGS\n\nBY\n\nJ.R.R. TOLKIEN\n\n\n\n\n\nThree Rings for the Elven-kings under the sky,\n\nSeven for the Dwarf-lords in their halls of stone,\n\nNine for Mortal Men doomed to die,\n\nOne for the Dark Lord on his dark throne\n\nIn the Land of Mordor where the Shadows lie.\n\nOne Ring to rule them all, One Ring to find them,\n\nOne Ring to bring them all and in the darkness bind them\n\nIn the Land of Mordor where the Shadows lie.\n\n\n\n\n\nCONTENTS\n\n\nCOV'

# %%
matches_lotr = re.findall(r"\bs*he\b", contents, re.IGNORECASE)

# %%
df_lotr = pd.DataFrame({'pronoun': matches_lotr})
df_lotr['pronoun'] = df_lotr.pronoun.str.lower()

# %%
#Lord of the Rings

df_lotr.pronoun.value_counts(normalize=True) * 100
# Out:
# she    56.087955
# he     43.912045
# Name: pronoun, dtype: float64

# %%
#Pride and Prejudice
df.pronoun.value_counts(normalize=True) * 100
# Out:
# she    56.115843
# he     43.884157
# Name: pronoun, dtype: float64
